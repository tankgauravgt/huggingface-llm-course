# %% [markdown]
# <a href="https://colab.research.google.com/github/tankgauravgt/huggingface-llm-course/blob/main/02_transformers_what_can_they_do.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# development version which comes with dependencies:
# !pip install transformers[sentencepiece] >> /dev/null

# %%
# import libraries:
from transformers import pipeline
import os

# disable logging:
from transformers.utils.logging import disable_progress_bar
disable_progress_bar()

# %% [markdown]
# The most basic object in the 🤗 Transformers library is the pipeline() function. It connects a model with its necessary preprocessing and postprocessing steps, allowing us to directly input any text and get an intelligible answer:

# %% [markdown]
# ## Available pipelines for different modalities
#
# The pipeline() function supports multiple modalities, allowing you to work with text, images, audio, and even multimodal tasks. In this course we’ll focus on text tasks, but it’s useful to understand the transformer architecture’s potential, so we’ll briefly outline it.

# %% [markdown]
# Here’s an overview of what’s available:
#
# - For a full and updated list of pipelines, see the [🤗 Transformers documentation](https://huggingface.co/docs/hub/en/models-tasks).

# %% [markdown]
# ### Text pipelines
#
# - **text-generation:** Generate text from a prompt
# - **text-classification:** Classify text into predefined categories
# - **summarization:** Create a shorter version of a text while preserving key information
# - **translation:** Translate text from one language to another
# - **zero-shot-classification:** Classify text without prior training on specific labels
# - **feature-extraction:** Extract vector representations of text

# %%
text_generator = pipeline(
    task="text-generation",
    model="gpt2",
    device="cpu"
)
responses = text_generator(["Cricket is"])
responses
# Out:
# Device set to use cpu
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [[{'generated_text': "Cricket is a world class sport and has helped millions of people to excel in it. This is not a new phenomenon. It has been around for a long time. In fact, cricket is so popular in India that it has become one of the most popular sports in the world.\n\nThe sport is an international sport. The International Cricket Council (ICC) is the international body that has developed the World Cricket Council (WCC). The World Cricket Council is the body that sets guidelines in international cricket and the ICC is responsible for implementing them.\n\nIn the last five years, ITC has been responsible for the development of the format of cricket in various countries including Pakistan, Sri Lanka and Bangladesh. The ICC is responsible for implementing these rules. In some cases, these regulations have been adopted by the governing body and the ICC's decision is made by the ICC Director General.\n\nIn some cases, decisions have been made by the ICC Director General and the decision is made by the ICC Director General at the ICC Board of Control for Cricket in India (BCCI).\n\nIndia has been one of the most successful countries in the world in the development of cricket in this country. In the last five years, the development of cricket in India has been a success by more than"}]]

# %% [markdown]
# ### Image pipelines
#
# - **image-to-text:** Generate text descriptions of images
# - **image-classification:** Identify objects in an image
# - **object-detection:** Locate and identify objects in images

# %% [markdown]
# ### Audio pipelines
#
# - **automatic-speech-recognition:** Convert speech to text
# - **audio-classification:** Classify audio into categories
# - **text-to-speech:** Convert text to spoken audio

# %% [markdown]
# ### Multimodal pipelines
# - **image-text-to-text:** Respond to an image based on a text prompt
