# %% [markdown]
# <a href="https://colab.research.google.com/github/tankgauravgt/huggingface-llm-course/blob/main/01-transformer-models/Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# development version which comes with dependencies:
# !pip install transformers[sentencepiece] >> /dev/null
